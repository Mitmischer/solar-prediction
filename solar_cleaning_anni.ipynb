# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller

# %%
# Setup
solar_ts = pd.read_csv("data/energy_charts.csv", sep=",", header=0)
solar_ts["Datum"] = pd.to_datetime(solar_ts["Datum"], utc=True)
solar_ts = solar_ts.set_index(keys="Datum", drop=True)
solar_ts


weather_ts = pd.read_csv("D:\\weather.csv")
weather_ts["date"] = pd.to_datetime(weather_ts["date"], utc=True)
weather_ts = weather_ts.set_index(keys="date", drop=True)
weather_ts
# Out:
#                            tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  \
# date
# 2015-01-01 00:00:00+00:00   3.6   1.0   5.7   2.1   0.0   230  15.8  40.7
# 2015-01-02 00:00:00+00:00   6.6   5.0   8.8   1.1   0.0   249  31.0  67.3
# 2015-01-03 00:00:00+00:00   4.1   3.0   5.3   0.3   0.0   255  25.2  52.9
# 2015-01-04 00:00:00+00:00   3.4   2.4   5.6   0.8   0.0   277  23.0  48.2
# 2015-01-05 00:00:00+00:00   2.5   1.2   3.6   0.0   0.0   250  14.8  42.1
# ...                         ...   ...   ...   ...   ...   ...   ...   ...
# 2024-05-01 00:00:00+00:00  19.3  12.4  25.3   0.0   0.0    83  16.2  43.9
# 2024-05-02 00:00:00+00:00  19.5  12.9  25.4   0.0   0.0    94  20.9  55.1
# 2024-05-03 00:00:00+00:00  14.4  11.1  17.6   0.0   0.0   217  13.0  36.4
# 2024-05-04 00:00:00+00:00  14.2  10.3  17.4   3.3   0.0   160   7.6  24.1
# 2024-05-05 00:00:00+00:00  12.2   7.6  14.8   0.8   0.0   225  14.8  46.8
#
#                              pres  tsun
# date
# ...
